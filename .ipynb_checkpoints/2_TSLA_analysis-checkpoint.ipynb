# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dropout, Dense, GRU
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import adfuller

# %%
stockdf = pd.read_csv("TSLA.csv",index_col=0, parse_dates=True, squeeze=True)

# %%
stockdf.head(5)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-07-10  52.444000  52.599998  51.563999  51.830002  51.830002  13054500
# 2015-07-13  52.450001  52.509998  51.209999  52.431999  52.431999  14801500
# 2015-07-14  52.419998  53.198002  52.102001  53.130001  53.130001   9538000
# 2015-07-15  53.348000  53.498001  52.416000  52.627998  52.627998  10108000
# 2015-07-16  52.844002  53.439999  52.632000  53.335999  53.335999   8080000

# %%
stockdf["2015"]
# Out:
# C:\Users\BABARB~1\AppData\Local\Temp/ipykernel_19004/3910743944.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   stockdf["2015"]
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-07-10  52.444000  52.599998  51.563999  51.830002  51.830002  13054500
# 2015-07-13  52.450001  52.509998  51.209999  52.431999  52.431999  14801500
# 2015-07-14  52.419998  53.198002  52.102001  53.130001  53.130001   9538000
# 2015-07-15  53.348000  53.498001  52.416000  52.627998  52.627998  10108000
# 2015-07-16  52.844002  53.439999  52.632000  53.335999  53.335999   8080000
# ...               ...        ...        ...        ...        ...       ...
# 2015-12-24  46.112000  46.375999  45.655998  46.113998  46.113998   3540000
# 2015-12-28  46.298000  46.396000  45.108002  45.790001  45.790001   9506500
# 2015-12-29  46.012001  47.543999  45.910000  47.438000  47.438000  12031500
# 2015-12-30  47.320000  48.726002  47.133999  47.618000  47.618000  18489500
# 2015-12-31  47.702000  48.689999  47.674000  48.001999  48.001999  13575000
#
# [122 rows x 6 columns]

# %%
stockdf["Adj Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stockdf.tail(5)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-07-02  244.296005  245.600006  237.119995  241.731995  241.731995
# 2020-07-06  255.337997  275.558014  253.207993  274.316010  274.316010
# 2020-07-07  281.002014  285.899994  267.342010  277.971985  277.971985
# 2020-07-08  281.000000  283.451996  262.268005  273.175995  273.175995
# 2020-07-09  279.398010  281.712006  270.256012  278.855988  278.855988
#
#                Volume
# Date
# 2020-07-02   86250500
# 2020-07-06  102849500
# 2020-07-07  107448500
# 2020-07-08   81556500
# 2020-07-09   58588000

# %%
stockdf["2018" : "2020"]["Adj Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stockdf["2018" : "2020"]["Volume"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
g=stockdf["Adj Close"].values
result=adfuller(g)
print('ADF Statistic: %f'%result[0])
print('p-value : %f'%result[1])
print(' Citical Values:')
for key , value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: 3.980002
# p-value : 1.000000
#  Citical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# Accpet H0 that series is non stationary

# %%
g=stockdf["Volume"].values
result=adfuller(g)
print('ADF Statistic: %f'%result[0])
print('p-value : %f'%result[1])
print(' Citical Values:')
for key , value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.657330
# p-value : 0.081717
#  Citical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# Accpet H0 that series is non stationary

# %% [markdown]
# below is TSF template
#
# default activation used is tanh

# %%
def do_difference(data, time_diff=1):
    df = []
    for row in range(time_diff, len(data)):
        df.append(data[row] - data[row - time_diff])
    return np.array(df)

def invert_difference(differenced_data, y_values):
    undiff = []
    index_to_start = len(differenced_data) + 1

    for i in range(len(differenced_data)):
        undiff.append(differenced_data[i] + y_values[-(index_to_start - i)])
    return undiff
    

def do_scaling(data):

    scaler = MinMaxScaler()
    scaler = scaler.fit(data.reshape(-1,1))
    scaledf = scaler.transform(data.reshape(-1,1))
    scaledf = scaledf.reshape(scaledf.shape[0])
    return scaler, scaledf

def invert_scaling(scaler, data):
    return scaler.inverse_transform(data).reshape(data.shape[0])
        

# given we have values of closing price for past 5 days, we want to predict the price of next day
def generate_sequence(data, lookback, target_col=None):
    traindf = []
    targetdf = []
    for i in range(len(data)):
        till_index = i +lookback
        if till_index <= len(data)-1:
            traindf.append(data[i: i + lookback])
            if target_col == None:
                targetdf.append(data[i+ lookback])
            else:
                targetdf.append(data[i+ lookback][target_col])
    return np.array(traindf), np.array(targetdf)


def train_test_split(x, y, train_percent=0.8):
    test_start_index = round(train_percent*len(x))
    trainx, trainy, testx, testy = x[0:test_start_index], y[0:test_start_index], x[test_start_index:], y[test_start_index:]
    return trainx, trainy, testx, testy

def lstm_model(trainx, trainy, neurons, lookback, features, epochs,batch_size=1, activation_func = "tanh"):
    X, y = trainx, trainy
    model = Sequential()
    # model.add(LSTM(4, activation='relu', input_shape=(n_steps, n_features)))
    model.add(LSTM(neurons, batch_input_shape=(batch_size,lookback, features), stateful=True))
    model.add(Dense(1)) 
    model.compile(optimizer='adam', loss='mean_squared_error')
    # X = X.reshape((X.shape[0], X.shape[1], n_features))
    X = X.reshape((X.shape[0], X.shape[1], features)) 
    history = model.fit(X, y, epochs=epochs, batch_size=batch_size, shuffle=False)
    return history, model

def plot_model_results(model):
    loss = model.history["loss"]
    plt.plot(loss)
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.show()
    # return loss

def bidirectional_model(trainx, trainy, input_neurons, hidden_neurons, lookback, features, epochs,batch_size=128, dropout=0.5):
    X, y = trainx, trainy
    model = Sequential()
    model.add(Bidirectional(LSTM(input_neurons,return_sequences=True, dropout=0.5, input_shape=(lookback, features))))
    model.add(Bidirectional(LSTM(hidden_neurons, dropout=0.5)))
    model.add(Dense(1))  
    model.compile(optimizer='adam', loss='mean_squared_error')
    X = X.reshape((X.shape[0], X.shape[1], features))
    history = model.fit(X, y, epochs=epochs, batch_size=batch_size, shuffle=False)
    return history, model

def GRU_model(trainx, trainy, input_neurons, hidden_neurons, lookback, features, epochs,batch_size=128, dropout=0.5):
    X, y = trainx, trainy
    model = Sequential()
    model.add(GRU (input_neurons, dropout=0.5, return_sequences = True, input_shape=(lookback, features)))
    model.add(GRU(hidden_neurons, dropout=0.5))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    X = X.reshape((X.shape[0], X.shape[1], features))
    history = model.fit(X, y, epochs=epochs, batch_size=batch_size, shuffle=False)
    return history, model

def predict_data(model, testx, features=1):
    predictx = testx.reshape(testx.shape[0], testx.shape[1], features)
    y_pred = model.predict(predictx,batch_size=1)
    return y_pred

def plot_predicted(testy, y_pred, original_y, model_name, scaler):
    
    y_pred_unscaled = scaler.inverse_transform(y_pred)
    testy_unscaled = scaler.inverse_transform(testy.reshape(testy.shape[0],1))
    testy_undiff = invert_difference(testy_unscaled,original_y)
    pred_y_undiff = invert_difference(y_pred_unscaled, original_y)
    plt.plot(testy_undiff, label="Actual")
    plt.plot(pred_y_undiff, label="Predicted")
    plt.legend(loc="best")
    plt.title("Model Name = " + str(model_name))

def evaluate_results(testy, y_pred, original_y, model_name, scaler):
    errors = y_pred - testy
    rmse = np.sqrt(np.square(errors).mean())
    mae = np.mean(np.abs(errors))
    print('Root Mean Square Error = ' + str(rmse))
    print("mean Absolute Error = " + str(mae))
    plot_predicted(testy, y_pred, original_y, model_name, scaler)

# %% [markdown]
# We will use both Adj Close column and Volume colume to predict Adj close the next day

# %%
diff_vol = do_difference(stockdf["Volume"])
diff_adj_close = do_difference(stockdf["Adj Close"])

# %%
stockdf["Adj Close"].iloc[1002:].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.plot(diff_adj_close)

# %%
plt.plot(diff_vol)

# %%
scaler_diff_adj_close, scaled_diff_adj_close = do_scaling(diff_adj_close)
scaler_diff_vol, scaled_diff_vol = do_scaling(diff_vol)

# %%
scaled_df = []
for i in range(0, len(scaled_diff_adj_close)):
    scaled_df.append([scaled_diff_adj_close[i], scaled_diff_vol[i]])

# %%
scaled_df = np.array(scaled_df)

# %%
scaled_df
# Out:
# array([[0.49279989, 0.42772188],
#        [0.49432243, 0.4018352 ],
#        [0.47529165, 0.42337574],
#        ...,
#        [0.54123267, 0.43825305],
#        [0.40719368, 0.32566328],
#        [0.5733314 , 0.33645847]])

# %%
scaled_df[1][0]
# Out:
# 0.40183520115207794

# %% [markdown]
# ## Given 5 past Adj closing prices and volumes, predict the next days Adj close price

# %%
dfx, dfy = generate_sequence(scaled_df, 5, 0)

# %%
trainx, trainy, testx, testy = train_test_split(dfx,dfy, train_percent=0.8)

# %%
trainx.shape
# Out:
# (1002, 5, 2)

# %%
testy.shape
# Out:
# (251,)

# %% [markdown]
# ### Neurons = 50
#
# ### past data taken = 5
#
# ### features = 2
#
# ### epochs = 30

# %%
history, model1 = lstm_model(trainx,trainy,50,5,2,30)
# Out:
# Epoch 1/30
# 1002/1002 [==============================] - 6s 4ms/step - loss: 0.0024
# Epoch 2/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 9.2397e-04
# Epoch 3/30
# 1002/1002 [==============================] - 5s 5ms/step - loss: 8.6601e-04
# Epoch 4/30
# 1002/1002 [==============================] - 5s 5ms/step - loss: 8.3709e-04
# Epoch 5/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 8.1735e-04
# Epoch 6/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 8.0191e-04
# Epoch 7/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.9102e-04
# Epoch 8/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.8570e-04
# Epoch 9/30
# 1002/1002 [==============================] - 5s 5ms/step - loss: 7.8058e-04
# Epoch 10/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.7092e-04
# Epoch 11/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.6648e-04
# Epoch 12/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.6017e-04
# Epoch 13/30
# 1002/1002 [==============================] - 5s 5ms/step - loss: 7.5488e-04
# Epoch 14/30
# 1002/1002 [==============================] - 5s 5ms/step - loss: 7.5074e-04
# Epoch 15/30
# 1002/1002 [==============================] - 5s 5ms/step - loss: 7.4708e-04
# Epoch 16/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.4269e-04
# Epoch 17/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.4021e-04
# Epoch 18/30
# 1002/1002 [==============================] - 5s 5ms/step - loss: 7.3715e-04
# Epoch 19/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.3428e-04
# Epoch 20/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.3168e-04
# Epoch 21/30
# 1002/1002 [==============================] - 5s 4ms/step - loss: 7.2931e-04
# Epoch 22/30
# 1002/1002 [==============================] - 5s 5ms/step - loss: 7.2713e-04
# Epoch 23/30
# 1002/1002 [==============================] - 5s 4ms/step - loss: 7.2506e-04
# Epoch 24/30
# 1002/1002 [==============================] - 5s 5ms/step - loss: 7.2316e-04
# Epoch 25/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.2153e-04
# Epoch 26/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.1996e-04
# Epoch 27/30
# 1002/1002 [==============================] - 5s 5ms/step - loss: 7.1845e-04
# Epoch 28/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.1706e-04
# Epoch 29/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.1576e-04
# Epoch 30/30
# 1002/1002 [==============================] - 4s 4ms/step - loss: 7.1453e-04

# %%
plot_model_results(history)

# %% [markdown]
# ### Input Neurons = 64
#
# ### Hidden neurons = 20
#
# ### past data taken = 5
#
# ### features = 2
#
# ### epochs = 30

# %%
history2, model2 = bidirectional_model(trainx, trainy, 64,20,5,2,30,)
# Out:
# Epoch 1/30
# 8/8 [==============================] - 14s 19ms/step - loss: 0.1158
# Epoch 2/30
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0173
# Epoch 3/30
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0146
# Epoch 4/30
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0096
# Epoch 5/30
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0076
# Epoch 6/30
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0061
# Epoch 7/30
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0058
# Epoch 8/30
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0050
# Epoch 9/30
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0049
# Epoch 10/30
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0044
# Epoch 11/30
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0038
# Epoch 12/30
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0039
# Epoch 13/30
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0034
# Epoch 14/30
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0032
# Epoch 15/30
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0029
# Epoch 16/30
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0027
# Epoch 17/30
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0026
# Epoch 18/30
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0022
# Epoch 19/30
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0022
# Epoch 20/30
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0021
# Epoch 21/30
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0019
# Epoch 22/30
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0017
# Epoch 23/30
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0016
# Epoch 24/30
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 25/30
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0013
# Epoch 26/30
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 27/30
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 28/30
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0012
# Epoch 29/30
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0012
# Epoch 30/30
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0011

# %%
plot_model_results(history2)

# %% [markdown]
# ### Input Neurons = 64
#
# ### Hidden Neurons = 20
#
# ### past data taken = 5
#
# ### features = 2
#
# ### epochs = 30

# %%
history3 , model3 = GRU_model(trainx, trainy, 64,20,5,2,30,)
# Out:
# Epoch 1/30
# 8/8 [==============================] - 7s 11ms/step - loss: 0.1049
# Epoch 2/30
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0319
# Epoch 3/30
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0208
# Epoch 4/30
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0169
# Epoch 5/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0112
# Epoch 6/30
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0100
# Epoch 7/30
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0086
# Epoch 8/30
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0076
# Epoch 9/30
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0065
# Epoch 10/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0063
# Epoch 11/30
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0060
# Epoch 12/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0050
# Epoch 13/30
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0049
# Epoch 14/30
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0041
# Epoch 15/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0036
# Epoch 16/30
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0034
# Epoch 17/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0032
# Epoch 18/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0031
# Epoch 19/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0026
# Epoch 20/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0026
# Epoch 21/30
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0023
# Epoch 22/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0023
# Epoch 23/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0022
# Epoch 24/30
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0021
# Epoch 25/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 26/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0019
# Epoch 27/30
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 28/30
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 29/30
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 30/30
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0018

# %%
lstm_pred = predict_data(model1,testx,2)
bidirec_pred= predict_data(model2,testx,2)
gru_pred = predict_data(model3,testx,2)

# %%
fig, axs = plt.subplots()
fig.set_figheight(10)
fig.set_figwidth(15)
evaluate_results(testy,lstm_pred,stockdf["Adj Close"], "LSTM",scaler_diff_adj_close )
# Out:
# Root Mean Square Error = 0.10194001869991104
# mean Absolute Error = 0.05935056366066789

# %%
fig, axs = plt.subplots()
fig.set_figheight(10)
fig.set_figwidth(15)
evaluate_results(testy,bidirec_pred,stockdf["Adj Close"], "Bidirectional",scaler_diff_adj_close)
# Out:
# Root Mean Square Error = 0.10237017551103075
# mean Absolute Error = 0.059419630067837875

# %%
evaluate_results(testy,gru_pred,stockdf["Adj Close"], "GRU",scaler_diff_adj_close )
# Out:
# Root Mean Square Error = 0.10359464391903148
# mean Absolute Error = 0.060960415585240006

# %% [markdown]
# All 3 models predicted quite well and accurately. The hyperparameters were ideal in this case which brought this result. The loss also decreases considerably after each epoch. RMSE and MAE were quite low in this case as well
